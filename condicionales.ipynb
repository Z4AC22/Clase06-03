# %% [markdown]
# Problema 1.
#
# En una celda pide lo siguiente
#
# 1. ¿Que fecha es hoy?
#
# 2. ¿En que fecha naciste?
#
# En otra celda
#
# determina si es tu cumpleaños o no

# %%
x=input('¿Que fecha es hoy?')
y=input('¿En que fecha naciste?')

# %%
z=x [0:18]
w=y [0:18]
if z == w:
    print('Feliz cumpleaños')
else:
    print('hoy no es tu cumleaños')

# %% [markdown]
# Problema 2
#
# En una celda
#
# 1. Pide un numero
#
# 2. Pide otro numero
#
# Realiza operaciones para que tengan el mismo valor ejemplo:
#
# Valor= 1
#
# Valor=2

# %%
x= int(input('ingresa un numero:'))
y= int(input('ingresa otro numero:'))
w=x*y
z= x+y
if w == z:
    print('el resultado de ambas operacieones es el mismo:',w,'y',z)
else:
    print('el resultado de las operaciones es diferente',w,'y',z )

# %% [markdown]
# Problema 3
#
# En una celda solicita:
#
# 1. Pide el codigo postal
#
# 2. Con ese codigo postal determina si esta dentro del rango de entrega
#
#  si su codigo esta entre 50000 y 50030 esta dentro del rango de entrega y puedes enviarle cosas, asi que publica un mensaje con ello, en caso contrario coloca un emoji triste y dile que no puedes entregarle nada

# %%
codigo=int(input('¿Cual es tu codigo postal?'))
if codigo >= 50000 and codigo <= 50030 :
    print ('estas dentro del rango de entrega y podemos enviarle cosas',"\U0001F600")
else:
    print("\U0001F640",'no podemos entregarle nada',"\U0001F63F")
